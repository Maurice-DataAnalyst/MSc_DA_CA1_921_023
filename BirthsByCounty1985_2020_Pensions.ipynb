# %%
import pandas as pd

# %%
births_url = "../data/BirthsByCounty1985_2020.csv"

# %%
births_df = pd.read_csv(births_url)

# %%
births_df.shape
# Out:
# (1332, 8)

# %%
births_df.head(20)
# Out:
#     Year                  County  All Births (Number) First Births (Number)  \
# 0   1985               ROI Total              62388.0                   NaN
# 1   1985             Dublin City               6645.0                   NaN
# 2   1985                  Fingal                  NaN                   NaN
# 3   1985  Dun Laoghaire Rathdown                878.0                   NaN
# 4   1985            South Dublin              10123.0                   NaN
# 5   1985                 Wicklow               1829.0                   NaN
# 6   1985                  Carlow                832.0                   NaN
# 7   1985                 Kildare               2466.0                   NaN
# 8   1985                Kilkenny               1286.0                   NaN
# 9   1985                   Laois                941.0                   NaN
# 10  1985                Longford                571.0                   NaN
# ...

# %%
births_df.describe()
# Out:
#               Year  All Births (Number)  Births within Marriage (Number)  \
# count  1332.000000          1259.000000                      1259.000000
# mean   2002.500000          3453.926926                      2473.647339
# std      10.392196          9972.518975                      7129.356646
# min    1985.000000             6.000000                         5.000000
# 25%    1993.750000           844.000000                       616.000000
# 50%    2002.500000          1382.000000                       969.000000
# 75%    2011.250000          2116.500000                      1671.000000
# max    2020.000000         75554.000000                     57106.000000
#
#        Births outside Marriage (Number)  Average Age of Mother (Years)  \
# count                       1259.000000                    1259.000000
# mean                         980.279587                      30.835504
# std                         3060.551775                       1.343217
# ...

# %%
births_df.describe(include=object)
# Out:
#              County First Births (Number)
# count          1332                  1087
# unique           37                   702
# top     Galway City                     .
# freq             36                    34

# %%
births_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1332 entries, 0 to 1331
# Data columns (total 8 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Year                                      1332 non-null   int64
#  1   County                                    1332 non-null   object
#  2   All Births (Number)                       1259 non-null   float64
#  3   First Births (Number)                     1087 non-null   object
#  4   Births within Marriage (Number)           1259 non-null   float64
#  5   Births outside Marriage (Number)          1259 non-null   float64
#  6   Average Age of Mother (Years)             1259 non-null   float64
#  7   Average Age of First Time Mother (Years)  1125 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 83.4+ KB
